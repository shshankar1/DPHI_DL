# %%
import pandas as pd
data = pd.read_csv('Testing_set_animals.csv')
data
# Out:
#        Image_1.jpg
# 0      Image_2.jpg
# 1      Image_3.jpg
# 2      Image_4.jpg
# 3      Image_5.jpg
# 4      Image_6.jpg
# ..             ...
# 394  Image_396.jpg
# 395  Image_397.jpg
# 396  Image_398.jpg
# 397  Image_399.jpg
# 398  Image_400.jpg
#
# [399 rows x 1 columns]

# %%
import numpy as np
data['label'] = np.random.choice(['mucca', 'pecora'], len(data))

# %%
data.label.to_list()
# Out:
# ['pecora',
#  'mucca',
#  'mucca',
#  'mucca',
#  'mucca',
#  'mucca',
#  'mucca',
#  'pecora',
#  'mucca',
#  'pecora',
#  'pecora',
#  'mucca',
#  'mucca',
#  'mucca',
#  'mucca',
#  'mucca',
#  'mucca',
#  'pecora',
#  'mucca',
#  'pecora',
#  'mucca',
#  'pecora',
#  'pecora',
#  'pecora',
#  'mucca',
#  'mucca',
#  'pecora',
#  'mucca',
#  'pecora',
#  'pecora',
#  'mucca',
#  'mucca',
#  'mucca',
#  'pecora',
#  'pecora',
#  'mucca',
#  'mucca',
#  'pecora',
#  'mucca',
#  'mucca',
#  'pecora',
#  'pecora',
#  'pecora',
#  'mucca',
#  'pecora',
#  'pecora',
#  'pecora',
#  'mucca',
#  'pecora',
#  'mucca',
#  'mucca',
#  'mucca',
#  'pecora',
#  'pecora',
#  'pecora',
#  'mucca',
#  'mucca',
#  'mucca',
#  'pecora',
#  'mucca',
#  'pecora',
#  'mucca',
#  'mucca',
#  'pecora',
#  'mucca',
#  'pecora',
#  'mucca',
#  'mucca',
#  'mucca',
#  'pecora',
#  'mucca',
#  'mucca',
#  'mucca',
#  'pecora',
#  'pecora',
#  'pecora',
#  'mucca',
#  'pecora',
#  'pecora',
#  'mucca',
# ...
